# %%
import json
import pandas as pd
import seaborn as sns

# %%
with open("vetting_playlist.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Inspect the type of data
print(type(data))


tdf = pd.json_normalize(data)
tdf.info()

tdftracks=[]
for i in tdf['tracks.items']:
    tdftracks.append(i)
# Out:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   collaborative                1 non-null      bool
#  1   description                  1 non-null      object
#  2   href                         1 non-null      object
#  3   id                           1 non-null      object
#  4   images                       1 non-null      object
#  5   name                         1 non-null      object
#  6   primary_color                0 non-null      object
#  7   public                       1 non-null      bool
#  8   snapshot_id                  1 non-null      object
#  9   type                         1 non-null      object
#  10  uri                          1 non-null      object
#  11  external_urls.spotify        1 non-null      object
#  12  followers.href               0 non-null      object
#  13  followers.total              1 non-null      int64
#  14  owner.display_name           1 non-null      object
#  15  owner.external_urls.spotify  1 non-null      object
#  16  owner.href                   1 non-null      object
#  17  owner.id                     1 non-null      object
#  18  owner.type                   1 non-null      object
#  19  owner.uri                    1 non-null      object
#  20  tracks.href                  1 non-null      object
#  21  tracks.items                 1 non-null      object
#  22  tracks.limit                 1 non-null      int64
#  23  tracks.next                  1 non-null      object
#  24  tracks.offset                1 non-null      int64
#  25  tracks.previous              0 non-null      object
#  26  tracks.total                 1 non-null      int64
# dtypes: bool(2), int64(4), object(21)
# memory usage: 330.0+ bytes

# %%
tdf.head()
# Out:
#    collaborative description  \
# 0          False
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/0bw8158RM...  0bw8158RM7roegphH1GYCx
#
#                                               images     name primary_color  \
# 0  [{'height': 640, 'url': 'https://mosaic.scdn.c...  Vetting          None
#
#    public                       snapshot_id      type  ...    owner.id  \
# 0    True  AAABIJSLYfVS0G/X1DWMDI3nNNKm6xlu  playlist  ...  1225630715
#
#   owner.type                owner.uri  \
# 0       user  spotify:user:1225630715
#
#                                          tracks.href  \
# 0  https://api.spotify.com/v1/playlists/0bw8158RM...
#
#                                         tracks.items tracks.limit  \
# 0  [{'added_at': '2017-06-23T23:21:59Z', 'added_b...          100
#
#                                          tracks.next tracks.offset  \
# 0  https://api.spotify.com/v1/playlists/0bw8158RM...             0
#
#   tracks.previous tracks.total
# 0            None          146
#
# [1 rows x 27 columns]

# %%
ttracks=pd.DataFrame(tdftracks)

# %%
ttracks.head()
# Out:
#                                                  0    \
# 0  {'added_at': '2017-06-23T23:21:59Z', 'added_by...
#
#                                                  1    \
# 0  {'added_at': '2017-04-21T17:02:44Z', 'added_by...
#
#                                                  2    \
# 0  {'added_at': '2017-06-12T22:46:03Z', 'added_by...
#
#                                                  3    \
# 0  {'added_at': '2017-04-15T00:53:05Z', 'added_by...
#
#                                                  4    \
# 0  {'added_at': '2017-06-29T23:13:06Z', 'added_by...
#
#                                                  5    \
# 0  {'added_at': '2017-04-15T00:54:34Z', 'added_by...
#
#                                                  6    \
# 0  {'added_at': '2017-04-15T00:55:17Z', 'added_by...
#
#                                                  7    \
# 0  {'added_at': '2017-04-15T00:58:29Z', 'added_by...
#
#                                                  8    \
# 0  {'added_at': '2017-07-22T19:07:37Z', 'added_by...
#
#                                                  9    ...  \
# 0  {'added_at': '2017-09-06T02:44:13Z', 'added_by...  ...
#
#                                                  136  \
# 0  {'added_at': '2024-03-06T16:23:29Z', 'added_by...
#
#                                                  137  \
# 0  {'added_at': '2024-03-06T16:23:50Z', 'added_by...
#
#                                                  138  \
# 0  {'added_at': '2024-03-25T19:55:00Z', 'added_by...
#
#                                                  139  \
# 0  {'added_at': '2024-04-16T20:28:54Z', 'added_by...
#
#                                                  140  \
# 0  {'added_at': '2024-07-01T20:30:46Z', 'added_by...
#
#                                                  141  \
# 0  {'added_at': '2024-07-02T05:22:56Z', 'added_by...
#
#                                                  142  \
# 0  {'added_at': '2024-10-06T05:22:15Z', 'added_by...
#
#                                                  143  \
# 0  {'added_at': '2024-10-06T05:24:37Z', 'added_by...
#
#                                                  144  \
# 0  {'added_at': '2024-11-07T23:54:43Z', 'added_by...
#
#                                                  145
# 0  {'added_at': '2024-12-12T22:41:56Z', 'added_by...
#
# [1 rows x 146 columns]

# %%
ttracks=ttracks.T

# %%
ttracks.head()
# Out:
#                                                    0
# 0  {'added_at': '2017-06-23T23:21:59Z', 'added_by...
# 1  {'added_at': '2017-04-21T17:02:44Z', 'added_by...
# 2  {'added_at': '2017-06-12T22:46:03Z', 'added_by...
# 3  {'added_at': '2017-04-15T00:53:05Z', 'added_by...
# 4  {'added_at': '2017-06-29T23:13:06Z', 'added_by...

# %%
ttracks = ttracks[0].apply(pd.Series)
ttracks.head()
# Out:
#                added_at                                           added_by  \
# 0  2017-06-23T23:21:59Z  {'external_urls': {'spotify': 'https://open.sp...
# 1  2017-04-21T17:02:44Z  {'external_urls': {'spotify': 'https://open.sp...
# 2  2017-06-12T22:46:03Z  {'external_urls': {'spotify': 'https://open.sp...
# 3  2017-04-15T00:53:05Z  {'external_urls': {'spotify': 'https://open.sp...
# 4  2017-06-29T23:13:06Z  {'external_urls': {'spotify': 'https://open.sp...
#
#    is_local primary_color                                              track  \
# 0     False          None  {'preview_url': None, 'available_markets': [],...
# 1     False          None  {'preview_url': None, 'available_markets': [],...
# 2     False          None  {'preview_url': None, 'available_markets': ['A...
# 3     False          None  {'preview_url': None, 'available_markets': [],...
# 4     False          None  {'preview_url': None, 'available_markets': [],...
#
#   video_thumbnail
# 0   {'url': None}
# 1   {'url': None}
# 2   {'url': None}
# 3   {'url': None}
# 4   {'url': None}

# %%
ttracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   added_at         146 non-null    object
#  1   added_by         146 non-null    object
#  2   is_local         146 non-null    bool
#  3   primary_color    0 non-null      object
#  4   track            146 non-null    object
#  5   video_thumbnail  146 non-null    object
# dtypes: bool(1), object(5)
# memory usage: 6.0+ KB

# %%
actual_tracks = ttracks['track'].apply(pd.Series)
actual_tracks.head()
# Out:
#   preview_url                                  available_markets  explicit  \
# 0        None                                                 []     False
# 1        None                                                 []     False
# 2        None  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False
# 3        None                                                 []     False
# 4        None                                                 []     False
#
#     type  episode  track                                              album  \
# 0  track    False   True  {'available_markets': [], 'type': 'album', 'al...
# 1  track    False   True  {'available_markets': [], 'type': 'album', 'al...
# 2  track    False   True  {'available_markets': ['AR', 'AU', 'AT', 'BE',...
# 3  track    False   True  {'available_markets': [], 'type': 'album', 'al...
# 4  track    False   True  {'available_markets': [], 'type': 'album', 'al...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    track_number  duration_ms              external_ids  \
# 0             3       215879  {'isrc': 'USFMT1406103'}
# 1             4       308066  {'isrc': 'USBQU1100085'}
# 2             2       181259  {'isrc': 'TCACH1515840'}
# 3             3       257920  {'isrc': 'USATO1400852'}
# 4             4       234973  {'isrc': 'USUG11400491'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/0N...
# 1  {'spotify': 'https://open.spotify.com/track/17...
# 2  {'spotify': 'https://open.spotify.com/track/1D...
# 3  {'spotify': 'https://open.spotify.com/track/51...
# 4  {'spotify': 'https://open.spotify.com/track/40...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/0NSEZeWHkYCk...  0NSEZeWHkYCknk1nAVO1Fh
# 1  https://api.spotify.com/v1/tracks/17ZnveSDBpG9...  17ZnveSDBpG9QtL7zLJNPy
# 2  https://api.spotify.com/v1/tracks/1DrlLvlYd1FI...  1DrlLvlYd1FIjNavRm6NdX
# 3  https://api.spotify.com/v1/tracks/51ggEZWbFP5d...  51ggEZWbFP5dMdWjGCDYTk
# 4  https://api.spotify.com/v1/tracks/40WXqoyOLAAu...  40WXqoyOLAAugGmJWZU1FY
#
#            name  popularity                                   uri  is_local
# 0   Better Than           0  spotify:track:0NSEZeWHkYCknk1nAVO1Fh     False
# 1  Only For You           0  spotify:track:17ZnveSDBpG9QtL7zLJNPy     False
# 2   Back Pocket          61  spotify:track:1DrlLvlYd1FIjNavRm6NdX     False
# 3         Dunes           0  spotify:track:51ggEZWbFP5dMdWjGCDYTk     False
# 4  All The Time          18  spotify:track:40WXqoyOLAAugGmJWZU1FY     False

# %%
actual_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   preview_url        0 non-null      object
#  1   available_markets  146 non-null    object
#  2   explicit           146 non-null    bool
#  3   type               146 non-null    object
#  4   episode            146 non-null    bool
#  5   track              146 non-null    bool
#  6   album              146 non-null    object
#  7   artists            146 non-null    object
#  8   disc_number        146 non-null    int64
#  9   track_number       146 non-null    int64
#  10  duration_ms        146 non-null    int64
#  11  external_ids       146 non-null    object
#  12  external_urls      146 non-null    object
#  13  href               146 non-null    object
#  14  id                 146 non-null    object
#  15  name               146 non-null    object
#  16  popularity         146 non-null    int64
#  17  uri                146 non-null    object
#  18  is_local           146 non-null    bool
# dtypes: bool(4), int64(4), object(11)
# memory usage: 17.8+ KB
